# %%
import numpy as np

embeddings = np.load('video_embeddings.npy')

embeddings
# Out:
# array([[-0.06390832, -0.08163419,  0.07024264, ..., -0.02763387,
#         -0.08460777, -0.0232206 ],
#        [-0.09820149,  0.00079689,  0.02492624, ...,  0.05146949,
#         -0.02615903,  0.05919499],
#        [-0.07675234,  0.00371606,  0.08637305, ...,  0.06323238,
#         -0.02694931,  0.00255118]], dtype=float32)

# %%
# %pip install sentence-transformers
from sentence_transformers.util import cos_sim


embeddings = embeddings

sim  = np.zeros((len(embeddings), len(embeddings)))

for i in range(len(embeddings)):
    sim[i:, i] = cos_sim(embeddings[i], embeddings[i:])

sim
# Out:
# Requirement already satisfied: sentence-transformers in c:\users\fahdk\anaconda3\lib\site-packages (3.1.0)
# Requirement already satisfied: transformers<5.0.0,>=4.38.0 in c:\users\fahdk\anaconda3\lib\site-packages (from sentence-transformers) (4.44.2)
# Requirement already satisfied: tqdm in c:\users\fahdk\anaconda3\lib\site-packages (from sentence-transformers) (4.66.4)
# Requirement already satisfied: torch>=1.11.0 in c:\users\fahdk\anaconda3\lib\site-packages (from sentence-transformers) (2.4.1)
# Requirement already satisfied: numpy<2.0.0 in c:\users\fahdk\anaconda3\lib\site-packages (from sentence-transformers) (1.26.4)
# Requirement already satisfied: scikit-learn in c:\users\fahdk\anaconda3\lib\site-packages (from sentence-transformers) (1.4.2)
# Requirement already satisfied: scipy in c:\users\fahdk\anaconda3\lib\site-packages (from sentence-transformers) (1.13.1)
# Requirement already satisfied: huggingface-hub>=0.19.3 in c:\users\fahdk\anaconda3\lib\site-packages (from sentence-transformers) (0.25.0)
# Requirement already satisfied: Pillow in c:\users\fahdk\anaconda3\lib\site-packages (from sentence-transformers) (10.3.0)
# Requirement already satisfied: filelock in c:\users\fahdk\appdata\roaming\python\python312\site-packages (from huggingface-hub>=0.19.3->sentence-transformers) (3.15.4)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\fahdk\anaconda3\lib\site-packages (from huggingface-hub>=0.19.3->sentence-transformers) (2024.3.1)
# Requirement already satisfied: packaging>=20.9 in c:\users\fahdk\anaconda3\lib\site-packages (from huggingface-hub>=0.19.3->sentence-transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\fahdk\anaconda3\lib\site-packages (from huggingface-hub>=0.19.3->sentence-transformers) (6.0.1)
# Requirement already satisfied: requests in c:\users\fahdk\anaconda3\lib\site-packages (from huggingface-hub>=0.19.3->sentence-transformers) (2.32.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\fahdk\anaconda3\lib\site-packages (from huggingface-hub>=0.19.3->sentence-transformers) (4.11.0)
# Requirement already satisfied: sympy in c:\users\fahdk\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.12)
# Requirement already satisfied: networkx in c:\users\fahdk\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\fahdk\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.4)
# Requirement already satisfied: setuptools in c:\users\fahdk\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (69.5.1)
# Requirement already satisfied: colorama in c:\users\fahdk\anaconda3\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\fahdk\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.38.0->sentence-transformers) (2023.10.3)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\fahdk\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.38.0->sentence-transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in c:\users\fahdk\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.38.0->sentence-transformers) (0.19.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\fahdk\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\fahdk\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers) (2.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\fahdk\anaconda3\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\fahdk\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.19.3->sentence-transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\fahdk\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.19.3->sentence-transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\fahdk\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.19.3->sentence-transformers) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\fahdk\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.19.3->sentence-transformers) (2024.8.30)
# Requirement already satisfied: mpmath>=0.19 in c:\users\fahdk\anaconda3\lib\site-packages (from sympy->torch>=1.11.0->sentence-transformers) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.
# array([[1.        , 0.        , 0.        ],
#        [0.32898894, 1.        , 0.        ],
#        [0.47181374, 0.35123619, 1.00000012]])

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


downsampled_embeddings = embeddings[: , :5]


sns.heatmap(downsampled_embeddings, annot=True)
# Out:
# <Axes: >
